# %%
#Linear Regression with Model Deployment 
import pandas as pd

# %%
df = pd.read_csv('Linear Regression/Data/Salary_Data.csv')

# %%
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
df.sample(3)
# Out:
#     YearsExperience   Salary
# 15              4.9  67938.0
# 8               3.2  64445.0
# 2               1.5  37731.0

# %%
df.shape
# Out:
# (30, 2)

# %%
df.columns
# Out:
# Index(['YearsExperience', 'Salary'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 612.0 bytes

# %%
df.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
x = df.drop(columns='Salary')

# %%
y=df['Salary']

# %%
y
# Out:
# 0      39343.0
# 1      46205.0
# 2      37731.0
# 3      43525.0
# 4      39891.0
# 5      56642.0
# 6      60150.0
# 7      54445.0
# 8      64445.0
# 9      57189.0
# 10     63218.0
# 11     55794.0
# 12     56957.0
# 13     57081.0
# 14     61111.0
# 15     67938.0
# 16     66029.0
# 17     83088.0
# 18     81363.0
# 19     93940.0
# 20     91738.0
# 21     98273.0
# 22    101302.0
# 23    113812.0
# 24    109431.0
# 25    105582.0
# 26    116969.0
# 27    112635.0
# 28    122391.0
# 29    121872.0
# Name: Salary, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
x_train
# Out:
#     YearsExperience
# 6               3.0
# 13              4.1
# 1               1.3
# 16              5.1
# 3               2.0
# 26              9.5
# 10              3.9
# 21              7.1
# 29             10.5
# 12              4.0
# 25              9.0
# 0               1.1
# 23              8.2
# 22              7.9
# 8               3.2
# 20              6.8
# 17              5.3
# 14              4.5
# 19              6.0
# 9               3.7
# 28             10.3
# 18              5.9
# 11              4.0
# 5               2.9

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model
# Out:
# LinearRegression()

# %%
#Training Data
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#test
y_pred = model.predict(x_test)

# %%
pd.DataFrame({'y_test':y_test,'y_pred':y_pred, 'MAE':y_pred-y_test})
# Out:
#       y_test         y_pred          MAE
# 27  112635.0  116648.994815  4013.994815
# 15   67938.0   72877.310194  4939.310194
# 2    37731.0   41212.687277  3481.687277
# 24  109431.0  108267.182866 -1163.817134
# 4    39891.0   47731.874349  7840.874349
# 7    54445.0   57044.998736  2599.998736

# %%
import numpy as np
from sklearn.metrics import mean_squared_error, r2_score,mean_absolute_error
print("Mean Absolute Error", mean_absolute_error(y_test,y_pred))
print("Mean Sqaure Error", mean_squared_error(y_test,y_pred))
print("Root Mean Square Error",np.sqrt(mean_squared_error(y_test,y_pred)))
print("R2 Score",r2_score(y_test,y_pred))
# Out:
# Mean Absolute Error 4006.61375085958
# Mean Sqaure Error 20370810.028187457
# Root Mean Square Error 4513.403375301997
# R2 Score 0.9780403439150969

# %%
#Value of M - Coefficient
model.coef_
# Out:
# array([9313.12438736])

# %%
#value of C - Intercept 
model.intercept_
# Out:
# np.float64(27243.00069640707)

# %%
#formula is y = m x + c and y = 9313.12438736 (x) + 27243.00069640707
y = (9313.12438736)*(1.5) + (27243.00069640707)

# %%
y
# Out:
# 41212.68727744707

# %%
model.predict([[1]]) #now model is predicting y value by its own
# Out:
# C:\Users\Lenovo\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([36556.12508377])

# %%
#visualize
import matplotlib.pyplot as plt
import seaborn as sns
plt.scatter(x_train,y_train)
plt.plot(x_test,y_pred, color='r')
plt.title("Year vs Experience")
plt.xlabel("Experience")
plt.ylabel("Salary")
plt.show()
